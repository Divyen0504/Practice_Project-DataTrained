# %%
#Lets start importing libraries

# %%
import pandas as pd

# %%
df=pd.read_csv("World_happiness.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#we will check the null values first

df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# there are no null values in the data

# %%
#we will drop the Region column as it will not affect our data and we will make country cloumn as index

# %%
df=df.drop(columns=['Region','Country'])

# %%
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 10 columns]

# %%
df.shape
# Out:
# (158, 10)

# %% [markdown]
# # EDA:

# %%
df.head(5)
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587         0.03411                   1.39651
# 1               2            7.561         0.04884                   1.30232
# 2               3            7.527         0.03328                   1.32548
# 3               4            7.522         0.03880                   1.45900
# 4               5            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df.tail(5)
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726

# %%
df.sample(5)
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 133             134            4.218         0.04828
# 114             115            4.610         0.04290
# 110             111            4.681         0.04412
# 100             101            4.867         0.08742
# 96               97            4.898         0.09438
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 133                   1.01216  1.10614                   0.76649  0.30587
# 114                   0.27100  1.03276                   0.33475  0.25861
# 110                   0.79907  1.20278                   0.67390  0.25123
# 100                   0.71206  1.07284                   0.07566  0.30658
# 96                    0.37545  1.04103                   0.07612  0.31767
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 133                        0.00872     0.11921            0.89991
# 114                        0.08079     0.18987            2.44191
# 110                        0.02961     0.15275            1.57140
# 100                        0.03060     0.18259            2.48676
# 96                         0.12504     0.16388            2.79832

# %%
df.dtypes
# Out:
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # Correlation and Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Rank                 158 non-null    int64
#  1   Happiness Score                158 non-null    float64
#  2   Standard Error                 158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 12.5 KB

# %% [markdown]
# we have int and float datatypes available in dataset now, we had country and region also as object but we dropped Region Column and set country as an index column

# %%
df_cor=df.corr()
df_cor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# Standard Error                       1.000000                 -0.217651
# Economy (GDP per Capita)            -0.217651                  1.000000
# Family                              -0.120728                  0.645299
# Health (Life Expectancy)            -0.310287                  0.816478
# Freedom                             -0.129773                  0.370300
# Trust (Government Corruption)       -0.178325                  0.307885
# Generosity                          -0.088439                 -0.010465
# Dystopia Residual                    0.083981                  0.040059
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Rank                -0.733644                 -0.735613 -0.556886
# Happiness Score                0.740605                  0.724200  0.568211
# Standard Error                -0.120728                 -0.310287 -0.129773
# Economy (GDP per Capita)       0.645299                  0.816478  0.370300
# Family                         1.000000                  0.531104  0.441518
# Health (Life Expectancy)       0.531104                  1.000000  0.360477
# Freedom                        0.441518                  0.360477  1.000000
# Trust (Government Corruption)  0.205605                  0.248335  0.493524
# Generosity                     0.087513                  0.108335  0.373916
# Dystopia Residual              0.148117                  0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Standard Error                          0.083981
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
type(df_cor)
# Out:
# pandas.core.frame.DataFrame

# %%
df.corr()['Happiness Score']
# Out:
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %%
df.corr()['Happiness Score'].sort_values()      #Economy is 1st, Family is 2nd, Health is 3rd
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# # Correlation using heatmap:

# %%
plt.figure(figsize=(10,6))          # Graphical presentation of Correlation
sns.heatmap(df_cor,annot=True,linewidths=2,linecolor="Darkgreen",cmap="YlOrRd_r",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Observations from the correlation:

# %%
df=df.drop(columns=['Happiness Rank'])

# %%
df.shape
# Out:
# (158, 9)

# %%
df.head()
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# # Describing Dataset:

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %%
plt.figure(figsize=(13,10))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=20)
plt.yticks(fontsize=14)
plt.title('Variables Summery')
plt.show()

# %% [markdown]
# # outcome of Describe Dataset:

# %%
sns.pairplot(df)

# %% [markdown]
# # Outliers Checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.plot(kind='box',subplots=True,layout=(4,4),figsize=(14,18),color='red')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# # Checking distribution and Skewness:

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %% [markdown]
# the data is normalised. the building blocks are normally distributed

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %% [markdown]
# the data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %% [markdown]
# The data is not normalised. the buliding blocks are out of the normalised curve

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %% [markdown]
# The data is not normalised. the building blocks are out of the normalised curve

# %% [markdown]
# # Scatter Plot:

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %% [markdown]
# We can see that as Economy (GDP per Capita) is more Happiness Score of country is also more

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %% [markdown]
# We can see that Family and Happiness Score is directly proportional to each other

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %% [markdown]
# Health(life Expectancy) and Happiness score is also directly proportional to each other

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %% [markdown]
# As Freedom is more Happiness Score is also high

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %% [markdown]
# as Trust(Government Corruption)increases,Happiness Score is decreases

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %% [markdown]
# Generosity have not much effect initially but when it increases Happiness Score is decreases after

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# # Z score Technique:

# %%
from scipy.stats import zscore
import numpy as np

# %%
zscore(df)
# Out:
# array([[ 1.93736005, -0.80592569,  1.36962124, ...,  2.30965159,
#          0.47103971,  0.75825809],
#        [ 1.91458063,  0.05588945,  1.13522625, ..., -0.01647953,
#          1.57585637,  1.09285682],
#        [ 1.88479215, -0.8544869 ,  1.19286069, ...,  2.8427738 ,
#          0.8242928 ,  0.71233526],
#        ...,
#        [-2.0761992 ,  0.13253425, -0.45524543, ...,  0.38141902,
#          1.85689094, -3.20843049],
#        [-2.1646885 ,  2.26396166, -2.06756644, ..., -0.35771452,
#         -0.31694987, -0.48198451],
#        [-2.22251319,  1.13418227, -1.58633379, ..., -0.30180313,
#         -0.5581534 , -0.96361241]])

# %%
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 9)

# %%
z
# Out:
# array([[1.93736005, 0.80592569, 1.36962124, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.91458063, 0.05588945, 1.13522625, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.88479215, 0.8544869 , 1.19286069, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [2.0761992 , 0.13253425, 0.45524543, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [2.1646885 , 2.26396166, 2.06756644, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [2.22251319, 1.13418227, 1.58633379, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
# will remove the outliers in a way that keeps only those data points that fall under the 3 standard deviations.

# %%
df_new = df[(z<3).all(axis=1)]

# %%
print("old DataFrame",df.shape)
print("New DataFrame",df_new.shape)
print("total dropped rows",df.shape[0]-df_new.shape[0])
# Out:
# old DataFrame (158, 9)
# New DataFrame (149, 9)
# total dropped rows 9

# %% [markdown]
# # Precentage Data Loss:

# %%
loss_percent=(158-149)/158*100
print('loss_percent:-',loss_percent,'%')
# Out:
# loss_percent:- 5.69620253164557 %

# %% [markdown]
# # Spliiting the data into x and y:

# %%
df_new.columns
# Out:
# Index(['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Splitting tha data into x Dataset

x=df_new[['Economy (GDP per Capita)','Family',
         'Health (Life Expectancy)','Freedom','Trust (Government Corruption)',
         'Generosity','Dystopia Residual']]

# %%
# splitting the data in y Dataset

y=df_new['Happiness Score']

# %%
x.shape
# Out:
# (149, 7)

# %%
y.shape
# Out:
# (149,)

# %%
x      #independent variables
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 150                        0.17922     0.20165            1.41723
# 151                        0.12832     0.21747            1.46494
# 152                        0.09719     0.36510            1.95210
# 154                        0.08010     0.18260            1.63328
# 156                        0.10062     0.19727            1.83302
#
# [149 rows x 7 columns]

# %%
y      #target Variable
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
x.dtypes
# Out:
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # Relationship Between Target and Feature vectors:

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in x:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Happiness Score',fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# • Economy,Family,Health,Freedom,Dystopia Residual,have impact on happiness score,as these increases,Happiness rank also increases.
#
# • Trust and generosity has less impact,as trust goes down,happiness score goes down and same with the generosity.

# %% [markdown]
# # Tranforming data to remove skewness:

# %%
# from sklearn.preprocessing import power_transform
# x=power_tranform(x,method='yeo-johnson')
# x

# %% [markdown]
# # Standard scaler:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
# sc=StandardScaler()
x_scaled=normalize(x, norm='l2', axis=1)
x_scaled
# Out:
# array([[0.40823528, 0.39449599, 0.27520386, ..., 0.12271234, 0.08675632,
#         0.735894  ],
#        [0.36883503, 0.39713092, 0.26844139, ..., 0.0400606 , 0.12356619,
#         0.76524658],
#        [0.39334322, 0.40375933, 0.25955406, ..., 0.14350196, 0.10130929,
#         0.73952609],
#        ...,
#        [0.15433351, 0.14614441, 0.14638569, ..., 0.04690036, 0.17618399,
#         0.94201253],
#        [0.15897271, 0.19624659, 0.1769691 , ..., 0.04442252, 0.10126781,
#         0.90579785],
#        [0.00801236, 0.2177842 , 0.11728412, ..., 0.05269302, 0.10330702,
#         0.95992207]])

# %% [markdown]
# # Since the outcome is Continous values we will use Linear Regression on model.

# %%
#importing Machine Learning Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
import pickle
from sklearn.metrics import adjusted_rand_score

# %%
print(x_scaled.shape)
# Out:
# (149, 7)

# %%
print(y.shape)
# Out:
# (149,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,random_state=45,test_size=0.25)

# %%
x_train.shape
# Out:
# (111, 7)

# %%
x_test.shape
# Out:
# (38, 7)

# %%
y_train.shape
# Out:
# (111,)

# %%
y_test.shape
# Out:
# (38,)

# %% [markdown]
# # Linear Regression

# %%
# Linear Regression:
lr=LinearRegression()

# training
lr.fit(x_train, y_train)

# prediction
y_pred_lr = lr.predict(x_test)

# The coefficients
print("Coefficients:#n",lr.coef_)

# The mean squared error
print("Mean squarede error: %.2f" % mean_squared_error(y_test, y_pred_lr))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-Square: %.2f" % r2_score(y_test,y_pred_lr))

# plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Coefficients:#n [ 8.14357185  4.71382616  3.80983028  2.8942188   6.74612079  1.97140428
#  11.56869057]
# Mean squarede error: 0.84
# Coefficient of determination/R-Square: 0.40

# %%
# Cross Valiodation
from sklearn.model_selection import cross_val_score
k = 5
cv_result = cross_val_score(lr,x_train,y_train,cv=k) # uses R^2 as score
print('cv Scores: ',cv_result)
print('cv scores average: ',np.sum(cv_result)/k)
# Out:
# cv Scores:  [ 0.44597793  0.46360195  0.15939744  0.20336491 -0.01063772]
# cv scores average:  0.2523409027378711

# %% [markdown]
# # Decision Tree Regression

# %%
# Decicion tree regression
dt=DecisionTreeRegressor()

# training
dt.fit(x_train, y_train)

# prediction
y_pred_dt = dt.predict(x_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_dt))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient od determination/R-Square: %.2f" % r2_score(y_test, y_pred_dt))

# plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_dt, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Mean squared error: 0.79
# Coefficient od determination/R-Square: 0.43

# %%
# grid search cross validation with 1 hyperparameter
from sklearn.model_selection import GridSearchCV
grid = {'min_samples_leaf': np.arange(1,10),"criterion":["mse","friedman_mse","mae"]}

dt_cv = GridSearchCV(dt, grid, cv=5) # GridSearchCV
dt_cv.fit(x_train,y_train) # Fit

# Print hyperparameter
print("Tuned hyperparameter k: {}".format(dt_cv.best_params_)) 
print("Best score: {}".format(dt_cv.best_score_))
# Out:
# Tuned hyperparameter k: {'criterion': 'mse', 'min_samples_leaf': 9}
# Best score: 0.28427176955542105

# %% [markdown]
# # Random Forest Regression

# %%
# Random forest regression
rf=RandomForestRegressor()

# training
rf.fit(x_train, y_train)

# prediction
y_pred_rf = rf.predict(x_test)

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred_rf))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-Square: %.2f" % r2_score(y_test, y_pred_rf))

# Plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_rf, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Mean squared error: 0.58
# Coefficient of determination/R-Square: 0.58

# %%
# grid search cross validation with 1 hyperparameter
grid = {'min_samples_leaf': np.arange(1,10),"criterion":["mse","friedman_mse","mae"]}

rf_cv = GridSearchCV(rf, grid, cv=5) # GridSearchCV
rf_cv.fit(x_train,y_train) # Fit

# print hyperparameter
print("Tuned hyperparameter k: {}".format(rf_cv.best_params_))
print("Best score: {}".format(rf_cv.best_score_))
# Out:
# Tuned hyperparameter k: {'criterion': 'mse', 'min_samples_leaf': 2}
# Best score: 0.4963504801672188

# %% [markdown]
# # Support Vector Regression

# %%
# SV regression
svr = SVR()

# training
svr.fit(x_train, y_train)

# prediction
y_pred_svr = svr.predict(x_test)

# The mean squared error
print("Mean squared error: %.2f" %mean_squared_error(y_test, y_pred_svr))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-Square: %.2f" % r2_score(y_test, y_pred_svr))

# plot outputs
# plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_svr, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Mean squared error: 0.89
# Coefficient of determination/R-Square: 0.36

# %%
# grid search cross validation with 1 hyperparameter

grid = {'kernel' : ('linear','poly','rbf','sigmoid'),'C' : [1,5,10],'degree' : [3,8],'coef0' : [0.10,10,0.5],'gamma' : ('auto','scale')}

svr_cv = GridSearchCV(svr, grid, cv=3) # GridSearchCV
svr_cv.fit(x_train,y_train) # Fit

# print hyperparameter
print("Tuned hyperparameter k: {}".format(svr_cv.best_params_))
print("Best score: {}".format(svr_cv.best_score_))
# Out:
# Tuned hyperparameter k: {'C': 10, 'coef0': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# Best score: 0.4064362877125067

# %% [markdown]
# # KNN Regression

# %%
# KNN regression
knn = KNeighborsRegressor()

# training
knn.fit(x_train, y_train)

# prediction
y_pred_knn = knn.predict(x_test)

# The mean squared error
print("Mean squared error: %.2f" %mean_squared_error(y_test, y_pred_knn))

# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination/R-square: %.2f" % r2_score(y_test, y_pred_knn))

# Plot outputs
#plt.scatter(x_test[:,1], y_test, color="black")
plt.scatter(y_test, y_pred_knn, color="blue", linewidth=3, marker=".")

plt.xlabel("y_test")
plt.ylabel("y_pred")

plt.show()
# Out:
# Mean squared error: 0.68
# Coefficient of determination/R-square: 0.51

# %%
# Cross Valiodation
k = 5
knn_cv = cross_val_score(knn,x_train,y_train,cv=k) # uses R^2 as score
print('CV Scores: ',knn_cv)
print('CV scores average: ',np.sum(knn_cv)/k)
# Out:
# CV Scores:  [ 0.22810703  0.61211507 -0.07648159  0.47570284  0.41018587]
# CV scores average:  0.32992584532653446

# %% [markdown]
# # Evaluation metrics:

# %%
sq_errorlr=mean_squared_error(y_test,y_pred_lr)
sq_errordtr=mean_squared_error(y_test,y_pred_dt)
sq_errorrfr=mean_squared_error(y_test,y_pred_rf)
sq_errorsvr=mean_squared_error(y_test,y_pred_svr)
sq_errorknr=mean_squared_error(y_test,y_pred_knn)

rmse_lr=sqrt(sq_errorlr)                              #rmse=root mean squared error
rmse_svr=sqrt(sq_errorsvr)
rmse_dtr=sqrt(sq_errordtr)
rmse_rfr=sqrt(sq_errorrfr)
rmse_knr=sqrt(sq_errorknr)

print("RMSE of Linear Regression is: ", rmse_lr)
print("RMSE of Decision Tree Regressor is: ", rmse_dtr)
print("RMSE of Random Forest Regressor is: ", rmse_rfr)
print("RMSE of Support Vector Regression is: ", rmse_svr)
print("RMSE of K Neighbors Regressor is: ", rmse_knr)
# Out:
# RMSE of Linear Regression is:  0.9158115351731843
# RMSE of Decision Tree Regressor is:  0.8913770688924908
# RMSE of Random Forest Regressor is:  0.7642667022708762
# RMSE of Support Vector Regression is:  0.9416606307187911
# RMSE of K Neighbors Regressor is:  0.8239565350059112

# %% [markdown]
# Support Vector Regression has the lowest RMSE,followed by linear regression,KNN regressor, random forest regressor, and decision tree regressor

# %%
 #R2 Score for the model:
    
print("R2 Score for Linear Regression is:",r2_score(y_test,y_pred_lr))
print("R2 Score for Decision Tree Regressor is:",r2_score(y_test,y_pred_dt))
print("R2 Score for Random Forest Regressor is:",r2_score(y_test,y_pred_rf))
print("R2 Score for Support Vector Regression is:",r2_score(y_test,y_pred_svr))
print("R2 Score for K Neighbors Regressor is:",r2_score(y_test,y_pred_knn))
# Out:
# R2 Score for Linear Regression is: 0.3990923301193319
# R2 Score for Decision Tree Regressor is: 0.4307298087632625
# R2 Score for Random Forest Regressor is: 0.5815096908638557
# R2 Score for Support Vector Regression is: 0.3646919536899502
# R2 Score for K Neighbors Regressor is: 0.5135881646167466

# %% [markdown]
# We use R2 score to evaluate the model and check the accuracy by which we would be able to choose our best regression model.

# %% [markdown]
# Support Vector Regression has the highest R2 score, followed by linear regression, KNN regression, random forest regressor, and decision tree regressor

# %% [markdown]
# # Support Vector Regressor (SVR) is the best performing model

# %% [markdown]
# SVR has the highrst R2 score of 95% and the lowest RMSE of 26% as compared to all the other models

# %% [markdown]
# Saving the model:

# %%
file="Final_world_Happiness.pkl"
pickle.dump(svr,open(file,'wb'))

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(svr.predict(x_test))
df_com=pd.DataFrame({"original":a,"predicted":predicted}, index=range(len(a)))
df_com
# Out:
#     original  predicted
# 0      7.587   6.063871
# 1      5.987   5.818360
# 2      4.218   5.095510
# 3      7.522   6.091737
# 4      6.329   5.718210
# 5      5.984   5.926324
# 6      6.269   5.566385
# 7      4.550   4.951446
# 8      4.350   5.636191
# 9      3.819   5.048031
# 10     6.574   5.533960
# 11     3.956   4.629963
# 12     4.565   5.214100
# 13     4.786   4.859882
# 14     3.995   4.358156
# 15     6.302   5.623139
# 16     3.655   5.046808
# 17     3.681   4.581272
# 18     6.123   5.188251
# 19     5.057   4.329443
# 20     5.102   5.511827
# 21     5.098   5.756646
# 22     4.518   4.482422
# 23     5.855   5.806913
# 24     7.427   5.939037
# 25     4.610   4.496866
# 26     4.959   5.767537
# 27     5.605   5.614063
# 28     7.278   5.599911
# 29     4.971   4.223050
# 30     5.212   5.953080
# 31     4.739   5.725204
# 32     3.896   5.722842
# 33     4.800   5.374280
# 34     6.750   5.957165
# 35     3.904   4.704005
# 36     7.187   5.371440
# 37     6.670   5.662966

# %% [markdown]
# # Loading the model:

# %%
load_model=pickle.load(open(file,'rb'))
result=load_model.score(x_test,y_test)*100
print(result)
# Out:
# 36.469195368995024

# %% [markdown]
# Finally I have loaded the saved model and passed the unseen data set to predict the model score.

# %%
plt.xlabel('original score')
plt.ylabel('predicted score')
plt.scatter(y_test,y_pred_svr,color='blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
